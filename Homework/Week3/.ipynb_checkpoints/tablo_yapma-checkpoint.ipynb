# %%
import pandas as pd

# %%
df1 = pd.read_csv ("HousingData.csv")
df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df1.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1["CRIM"].mean()
# Out:
# np.float64(3.6118739711934156)

# %%
df1["CRIM"] = df1["CRIM"].fillna( df1["CRIM"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM        0
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
df1["ZN"].mean()
# Out:
# np.float64(11.2119341563786)

# %%
df1["ZN"] = df1["ZN"].fillna( df1["ZN"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1["INDUS"].mean()
# Out:
# np.float64(11.083991769547325)

# %%
df1["INDUS"] = df1["INDUS"].fillna( df1["INDUS"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1["CHAS"].mean()
# Out:
# np.float64(0.06995884773662552)

# %%
df1["CHAS"] = df1["CHAS"].fillna( df1["CHAS"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1["AGE"].mean()
# Out:
# np.float64(68.51851851851852)

# %%
df1["AGE"] = df1["AGE"].fillna( df1["AGE"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM        0
# ZN          0
# INDUS       0
# CHAS        0
# NOX         0
# RM          0
# AGE         0
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df1["LSTAT"].mean()
# Out:
# np.float64(12.715432098765433)

# %%
df1["LSTAT"] = df1["LSTAT"].fillna( df1["LSTAT"].mean() )

# %%
df1.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT  MEDV
# ...

# %%
df1.to_csv("boston_housing_cleaned.csv", index=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
df1 = pd.read_csv ("boston_housing_cleaned.csv")
df1
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT  MEDV
# ...

# %%
x=df1["AGE"]
y=df1["MEDV"]
x,y
# Out:
# (0      65.200000
#  1      78.900000
#  2      61.100000
#  3      45.800000
#  4      54.200000
#           ...
#  501    69.100000
#  502    76.700000
#  503    91.000000
#  504    89.300000
#  505    68.518519
#  Name: AGE, Length: 506, dtype: float64,
#  0      24.0
#  1      21.6
#  2      34.7
#  3      33.4
#  4      36.2
#         ...
#  501    22.4
#  502    20.6
#  503    23.9
#  504    22.0
#  505    11.9
#  Name: MEDV, Length: 506, dtype: float64)

# %%
x=df1["AGE"]
y=df1["MEDV"]
x,y
# Out:
# (0      65.200000
#  1      78.900000
#  2      61.100000
#  3      45.800000
#  4      54.200000
#           ...
#  501    69.100000
#  502    76.700000
#  503    91.000000
#  504    89.300000
#  505    68.518519
#  Name: AGE, Length: 506, dtype: float64,
#  0      24.0
#  1      21.6
#  2      34.7
#  3      33.4
#  4      36.2
#         ...
#  501    22.4
#  502    20.6
#  503    23.9
#  504    22.0
#  505    11.9
#  Name: MEDV, Length: 506, dtype: float64)

# %%
plt.figure(figsize=(12,7))
plt.bar(x,y , color="red")
plt.xlabel("1940’tan önce yapılmış evlerin oranı", fontsize=14,fontweight='bold')
plt.ylabel("Ortalama ev fiyatı",fontsize=14, fontweight='bold')
plt.title("1940’tan önce yapılmış evlerin oranı ve Ortalama ev fiyatı Grafiği",fontsize=16, fontweight='bold')
plt.grid(axis ='y', linestyle="--",alpha=0.7)

# %%
x1=df1["RM"]
y1=df1["AGE"]
x1,y1
# Out:
# (0      6.575
#  1      6.421
#  2      7.185
#  3      6.998
#  4      7.147
#         ...
#  501    6.593
#  502    6.120
#  503    6.976
#  504    6.794
#  505    6.030
#  Name: RM, Length: 506, dtype: float64,
#  0      65.200000
#  1      78.900000
#  2      61.100000
#  3      45.800000
#  4      54.200000
#           ...
#  501    69.100000
#  502    76.700000
#  503    91.000000
#  504    89.300000
#  505    68.518519
#  Name: AGE, Length: 506, dtype: float64)

# %%
plt.figure(figsize=(12,7))
plt.scatter(x1, y1, color="green", marker="o", s=25, edgecolor="black")
plt.xlabel("Bir evdeki ortalama oda sayısı",fontsize=14,fontweight='bold')
plt.ylabel("1940’tan önce yapılmış evlerin oranı",fontsize=14,fontweight='bold')
plt.title("Bir evdeki ortalama oda sayısı ve 1940’tan önce yapılmış evlerin oranı Grafiği",fontsize=16,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Bir evdeki ortalama oda sayısı ve 1940’tan önce yapılmış evlerin oranı Grafiği')
